# %% [markdown]
# ##### Pandas学习
# * 40分钟：pandas以及pandas书的教程。
# * 20分钟：Markdown语法讲解、Jupyter Report、作业。

# %% [markdown]
# #### 我的恩师和一些安利
# 1.Pandas的书：http://suo.im/5xD8nC
#
#
# 2.互联网挖掘实验室：http://weblab.com.cityu.edu.hk/blog/
#
#
# 3.https://seancheney.gitbook.io/python-for-data-analysis-2nd/di-05-zhang-pandas-ru-men

# %%
import pandas as pd

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
'''
import pandas as pd
import numpy as np
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four',
                            'five', 'six'])
'''

# %%
# https://zhuanlan.zhihu.com/p/52302383
# https://blog.csdn.net/lvsehaiyang1993/article/details/80473265
# 相关分析

# frame2.apply(lambda x:np.square(x) if x.name == "pop" else x)
# frame2.loc["one"]
# frame2.iloc[[1,2],[1,2]]
# frame2.describe()

import pandas as pd
import seaborn as sns
df = pd.read_csv("countries of the world.csv")
df = df.dropna()
df = df.iloc[:,2:].apply(lambda x: x.astype(str).str.replace(',','.').astype(float))
sns.regplot(x='GDP ($ per capita)', y='Phones (per 1000)', data=df)

# %%
# 示例数据1：豆瓣数据
import pandas as pd
pd.read_excel("douban_495books_clean.xlsx")

# 示例数据2：Amazon
import pandas as pd
import json
table_goods = pd.read_json("meta_Grocery_and_Gourmet_Food.json",lines=True)

# %%
# reviews
table_reviews = pd.read_json("Grocery_and_Gourmet_Food_5.json",lines=True)

# %%
table_goods[0:10000]
# Out:
#                                                  category  \
# 0       [Grocery & Gourmet Food, Dairy, Cheese & Eggs,...
# 1       [Grocery & Gourmet Food, Cooking & Baking, Sug...
# 2       [Grocery & Gourmet Food, Cooking & Baking, Fro...
# 3       [Grocery & Gourmet Food, Cooking & Baking, Fro...
# 4       [Grocery & Gourmet Food, Cooking & Baking, Fro...
# ...                                                   ...
# 287204  [Grocery & Gourmet Food, Jams, Jellies & Sweet...
# 287205  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 287206  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 287207  [Grocery & Gourmet Food, Herbs, Spices & Seaso...
# 287208  [Grocery & Gourmet Food, Beverages, Bottled Be...
#
#                                               description  \
# 0       [BEEMSTER GOUDA CHEESE AGED 18/24 MONTHS, Stat...
# 1       [Shipped from UK, please allow 10 to 21 busine...
# 2       [Jazz up your cakes with a sparkling monogram ...
# ...

# %%
# table_reviews.groupby(["reviewerID"])["overall"].mean().sort_values()
# groupby("reviewerID").count()["overall"].sort_values(ascending = False)
# table_goods
#import numpy as np
#table_reviews
table = pd.DataFrame(np.arange(9).reshape(3,3),columns=['year', 'state', 'pop'])
table
# Out:
#    year  state  pop
# 0     0      1    2
# 1     3      4    5
# 2     6      7    8

# %% [markdown]
# ###
# ####
#
# * 1.我研究的问题是：。。。。。。
